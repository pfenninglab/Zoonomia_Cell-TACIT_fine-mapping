# %%
suppressMessages(library(ArchR))
ss <- function(x, pattern, slot = 1, ...) { sapply(strsplit(x = x, split = pattern, ...), '[', slot) }
options(stringsAsFactors = F)
options(repr.plot.width=11, repr.plot.height=8.5)

# %%
##################################
### set Arrow File parameters ####
addArchRThreads(threads = 10)

##################################
### load rheMac10 ArchR genome ###
GENOMEDIR='/home/bnphan/resources/genomes/rheMac10'
load(file.path(GENOMEDIR,'rheMac10_liftoff_GRCh38.p13_ArchR_annotations.rda'))
# Out:
# Setting default number of Parallel threads to 10.

# %%
PROJDIR='../../../data/raw_data/rheMac10/Stauffer_caudate'
ARCHDIR=file.path(PROJDIR,'ArchR_Stauffer_caudate')
proj = loadArchRProject(ARCHDIR)
# Out:
# Successfully loaded ArchRProject!
#
#
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|

# %% [markdown]
# # Make plots

# %%
# # plot the confusion matrix of cell types by subjects
# cM <- confusionMatrix(paste0(proj$Clusters), paste0(proj$Sample))
# cM <- cM / Matrix::colSums(cM)
# p <- pheatmap::pheatmap(
#   mat = as.matrix(cM), 
#   color = paletteContinuous("whiteBlue"), 
#   border_color = "black")
# p

# %%
## make UMAP plots
p1 <- plotEmbedding(ArchRProj = proj, colorBy = "cellColData", 
                    name = "Clusters", embedding = "UMAP")

# p2 <- plotEmbedding(ArchRProj = proj, colorBy = "cellColData", 
#                     name = "Region", embedding = "UMAP")

# p3 <- plotEmbedding(ArchRProj = proj, colorBy = "cellColData", 
#                     name = "Sample", embedding = "UMAP")
# ggAlignPlots(p1, p2, type = "h")
p1
# Out:
# ArchR logging to : ArchRLogs/ArchR-plotEmbedding-18531bbfa6be-Date-2020-12-28_Time-08-50-39.log
# If there is an issue, please report to github with logFile!
#
# Getting UMAP Embedding
#
# ColorBy = cellColData
#
# Plotting Embedding
#
# 1
#
#
# ArchR logging successful to : ArchRLogs/ArchR-plotEmbedding-18531bbfa6be-Date-2020-12-28_Time-08-50-39.log
# plot without title

# %%
# Broad MSN marker, mouse 2010300C02Rik == human KIAA1211L
# MSN markers, Ppp1r1b = DARPP-32, Bcl11b=Ctip2
markMSN3 = c('Ppp1r1b','Bcl11b','Pde1b','Foxp1','Six3' )
p <- plotEmbedding( ArchRProj = proj, colorBy = "GeneScoreMatrix", 
                    name = markMSN3, embedding = "UMAP", imputeWeights = NULL)
p3 <- lapply(p, function(x){
  x + guides(color = FALSE, fill = FALSE) + 
    theme_ArchR(baseSize = 6.5) + theme(plot.margin = unit(c(0, 0, 0, 0), "cm")) +
    theme(  axis.text.x=element_blank(),  axis.ticks.x=element_blank(), 
            axis.text.y=element_blank(),  axis.ticks.y=element_blank())
})
do.call(cowplot::plot_grid, c(list(ncol = 3),p3))
# Out:
# ArchR logging to : ArchRLogs/ArchR-plotEmbedding-18533f3cc44a-Date-2020-12-28_Time-08-50-54.log
# If there is an issue, please report to github with logFile!
#
# Getting UMAP Embedding
#
# ColorBy = GeneScoreMatrix
#
# Getting Matrix Values...
#
# 2020-12-28 08:50:55 :
#
# 1
#
#
# Plotting Embedding
#
# 1
# 2
# 3
# 4
# 5
#
#
# ArchR logging successful to : ArchRLogs/ArchR-plotEmbedding-18533f3cc44a-Date-2020-12-28_Time-08-50-54.log
# plot without title

# %%
markMSN1 = c('Drd1','Tac1','Foxp2','Slc35d3','Chrm4', 'Pdyn') # D1 markers

# D1 MSN
p <- plotEmbedding( ArchRProj = proj, colorBy = "GeneScoreMatrix", 
                    name = markMSN1, embedding = "UMAP", imputeWeights = NULL) # 
p1 <- lapply(p, function(x){
  x + guides(color = FALSE, fill = FALSE) + 
    theme_ArchR(baseSize = 6.5) +
    theme(plot.margin = unit(c(0, 0, 0, 0), "cm")) +
    theme( axis.text.x=element_blank(),  axis.ticks.x=element_blank(), 
           axis.text.y=element_blank(),  axis.ticks.y=element_blank())
})
do.call(cowplot::plot_grid, c(list(ncol = 3),p1))
# Out:
# ArchR logging to : ArchRLogs/ArchR-plotEmbedding-18534a7f2ff8-Date-2020-12-28_Time-08-51-07.log
# If there is an issue, please report to github with logFile!
#
# Getting UMAP Embedding
#
# ColorBy = GeneScoreMatrix
#
# Getting Matrix Values...
#
# 2020-12-28 08:51:07 :
#
# 1
#
#
# Plotting Embedding
#
# 1
# 2
# 3
# 4
# 5
# 6
#
#
# ArchR logging successful to : ArchRLogs/ArchR-plotEmbedding-18534a7f2ff8-Date-2020-12-28_Time-08-51-07.log
# plot without title

# %%
markMSN2 = c('Drd2','Adora2a','Penk', 'Grik3', 'Sp9', 'Gpr52')# D2 markers

# D2 MSN
p <- plotEmbedding( ArchRProj = proj, colorBy = "GeneScoreMatrix", 
                    name = markMSN2, embedding = "UMAP", imputeWeights = NULL)
p2 <- lapply(p, function(x){
  x + guides(color = FALSE, fill = FALSE) + 
    theme_ArchR(baseSize = 6.5) + theme(plot.margin = unit(c(0, 0, 0, 0), "cm")) +
    theme(  axis.text.x=element_blank(),  axis.ticks.x=element_blank(), 
            axis.text.y=element_blank(),  axis.ticks.y=element_blank())
})
do.call(cowplot::plot_grid, c(list(ncol = 3),p2))
# Out:
# ArchR logging to : ArchRLogs/ArchR-plotEmbedding-185373e3cdb4-Date-2020-12-28_Time-08-51-37.log
# If there is an issue, please report to github with logFile!
#
# Getting UMAP Embedding
#
# ColorBy = GeneScoreMatrix
#
# Getting Matrix Values...
#
# 2020-12-28 08:51:38 :
#
# 1
#
#
# Plotting Embedding
#
# 1
# 2
# 3
# 4
# 5
# 6
#
#
# ArchR logging successful to : ArchRLogs/ArchR-plotEmbedding-185373e3cdb4-Date-2020-12-28_Time-08-51-37.log
# plot without title

# %%
## plot more interneuron markers
markerGenes1  <- c('Lhx6', "Pvalb", 'Sst', 'Chat','Th', 'Vip') # Interneuron markers

p <- plotEmbedding( ArchRProj = proj, colorBy = "GeneScoreMatrix", imputeWeights = NULL,
                    name = markerGenes1, embedding = "UMAP")
p <- lapply(p, function(x){
  x + guides(color = FALSE, fill = FALSE) + 
    theme_ArchR(baseSize = 6.5) + theme(plot.margin = unit(c(0, 0, 0, 0), "cm")) +
    theme(  axis.text.x=element_blank(),  axis.ticks.x=element_blank(), 
            axis.text.y=element_blank(),  axis.ticks.y=element_blank())
})
do.call(cowplot::plot_grid, c(list(ncol = 3),p))
# Out:
# ArchR logging to : ArchRLogs/ArchR-plotEmbedding-185333854a4c-Date-2020-12-28_Time-08-55-38.log
# If there is an issue, please report to github with logFile!
#
# Getting UMAP Embedding
#
# ColorBy = GeneScoreMatrix
#
# Getting Matrix Values...
#
# 2020-12-28 08:55:39 :
#
# 1
#
#
# Plotting Embedding
#
# 1
# 2
# 3
# 4
# 5
# 6
#
#
# ArchR logging successful to : ArchRLogs/ArchR-plotEmbedding-185333854a4c-Date-2020-12-28_Time-08-55-38.log
# plot without title

# %%
## Neuron vs. Glia markers
markerGenes1  <- c('Rbfox3', # Neuron
                   'Lhx6', #Interneuron
                   'Aqp4', # Astrocyte
                   'Cx3cr1', # Microglia
                   'Pdgfra', #OPC
                   'Mog' # Oligo
                  )

p <- plotEmbedding( ArchRProj = proj, colorBy = "GeneScoreMatrix", 
                    name = markerGenes1, embedding = "UMAP", imputeWeights = NULL)
p <- lapply(p, function(x){
  x + guides(color = FALSE, fill = FALSE) + 
    theme_ArchR(baseSize = 6.5) + theme(plot.margin = unit(c(0, 0, 0, 0), "cm")) +
    theme(  axis.text.x=element_blank(),  axis.ticks.x=element_blank(), 
            axis.text.y=element_blank(),  axis.ticks.y=element_blank())
})
do.call(cowplot::plot_grid, c(list(ncol = 3),p))
# Out:
# ArchR logging to : ArchRLogs/ArchR-plotEmbedding-1853207974d6-Date-2020-12-28_Time-08-54-46.log
# If there is an issue, please report to github with logFile!
#
# Getting UMAP Embedding
#
# ColorBy = GeneScoreMatrix
#
# Getting Matrix Values...
#
# 2020-12-28 08:54:46 :
#
# 1
#
#
# Plotting Embedding
#
# 1
# 2
# 3
# 4
# 5
# 6
#
#
# ArchR logging successful to : ArchRLogs/ArchR-plotEmbedding-1853207974d6-Date-2020-12-28_Time-08-54-46.log
# plot without title

# %% [markdown]
# # Relabel cluster and call peaks

# %%
############################################
# using marker gene scores, give cluster names
remapClust <- c(
    'C5'='Drop', # slushbucket MSNs, dead?
    'C11'='Drop',
    'C12'='Drop',
    'C15'='Drop',
    'C17'='Drop',

    'C1' = 'Microglia',
    'C2' = 'MSN_SN',
    
    'C4' = 'MSN_D1',
    'C6'='MSN_D1',

    'C3' = 'MSN_D2',
    'C7'='MSN_D2',
    
    'C8'='OPC',
    
    'C9'='Oligo',
    'C10'='Oligo',

    'C13'='Astro',
    'C14'='Astro',
    
    'C16'='INT_Pvalb'
)
proj$Clusters2 <- mapLabels(proj$Clusters, newLabels = remapClust, 
                            oldLabels = names(remapClust))
table(proj$Clusters2)
# Out:
#     Astro      Drop INT_Pvalb Microglia    MSN_D1    MSN_D2    MSN_SN     Oligo
#      1035       594       124       519       890       925        85      1442
#       OPC
#       304

# %%
## make UMAP plots
p1 <- plotEmbedding(ArchRProj = proj, colorBy = "cellColData", 
                    name = "Clusters2", embedding = "UMAP")

p1
# Out:
# ArchR logging to : ArchRLogs/ArchR-plotEmbedding-185352560a40-Date-2020-12-28_Time-08-58-39.log
# If there is an issue, please report to github with logFile!
#
# Getting UMAP Embedding
#
# ColorBy = cellColData
#
# Plotting Embedding
#
# 1
#
#
# ArchR logging successful to : ArchRLogs/ArchR-plotEmbedding-185352560a40-Date-2020-12-28_Time-08-58-39.log
# plot without title

# %%
# drop the drop clusters
ARCHDIR2=file.path(PROJDIR,'ArchR_Stauffer_caudate_labeled')
idxSample <- BiocGenerics::which(proj$Clusters2 %ni% "Drop")
cellsSample <- proj$cellNames[idxSample]

proj2 = subsetArchRProject(
  ArchRProj = proj,
  cells = cellsSample,
  outputDirectory = ARCHDIR2, force = TRUE
)
# Out:
# Dropping ImputeWeights Since You Are Subsetting Cells! ImputeWeights is a cell-x-cell Matrix!
#
# Copying ArchRProject to new outputDirectory : /projects/pfenninggroup/machineLearningForComputationalBiology/snATAC_cross_species_caudate/data/raw_data/rheMac10/Stauffer_caudate/ArchR_Stauffer_caudate_labeled
#
# Copying Arrow Files...
#
# .copyArrow : Initializing Out ArrowFile
#
# .copyArrow : Adding Metadata to Out ArrowFile
#
# .copyArrow : Adding SubMatrices to Out ArrowFile
#
# Getting ImputeWeights
#
# No imputeWeights found, returning NULL
#
# Copying Other Files...
#
# Copying Other Files (1 of 2): Embeddings
#
# Copying Other Files (2 of 2): IterativeLSI
#
# Saving ArchRProject...
#
# Loading ArchRProject...
#
# Successfully loaded ArchRProject!
#
#
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|

# %%
# make group coverage, call peaks, and 
proj2<-addGroupCoverages(proj2, groupBy="Clusters2", force = TRUE)
# Out:
# ArchR logging to : ArchRLogs/ArchR-addGroupCoverages-1853f9650e0-Date-2020-12-28_Time-09-04-34.log
# If there is an issue, please report to github with logFile!
#
# Astro (1 of 8) : CellGroups N = 2
#
# INT_Pvalb (2 of 8) : CellGroups N = 2
#
# Microglia (3 of 8) : CellGroups N = 2
#
# MSN_D1 (4 of 8) : CellGroups N = 2
#
# MSN_D2 (5 of 8) : CellGroups N = 2
#
# MSN_SN (6 of 8) : CellGroups N = 2
#
# Oligo (7 of 8) : CellGroups N = 2
#
# OPC (8 of 8) : CellGroups N = 2
#
# 2020-12-28 09:04:35 : Further Sampled 2 Groups above the Max Fragments!, 0.013 mins elapsed.
#
# 2020-12-28 09:04:35 : Creating Coverage Files!, 0.018 mins elapsed.
#
# 2020-12-28 09:04:35 : Batch Execution w/ safelapply!, 0.018 mins elapsed.
#
# 2020-12-28 09:11:17 : Adding Kmer Bias to Coverage Files!, 6.724 mins elapsed.
#
# Completed Kmer Bias Calculation
#
# Adding Kmer Bias (1 of 16)
#
# Adding Kmer Bias (2 of 16)
#
# Adding Kmer Bias (3 of 16)
#
# Adding Kmer Bias (4 of 16)
#
# Adding Kmer Bias (5 of 16)
#
# Adding Kmer Bias (6 of 16)
#
# Adding Kmer Bias (7 of 16)
#
# Adding Kmer Bias (8 of 16)
#
# Adding Kmer Bias (9 of 16)
#
# Adding Kmer Bias (10 of 16)
#
# Adding Kmer Bias (11 of 16)
#
# Adding Kmer Bias (12 of 16)
#
# Adding Kmer Bias (13 of 16)
#
# Adding Kmer Bias (14 of 16)
#
# Adding Kmer Bias (15 of 16)
#
# Adding Kmer Bias (16 of 16)
#
# 2020-12-28 09:17:31 : Finished Creation of Coverage Files!, 12.949 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addGroupCoverages-1853f9650e0-Date-2020-12-28_Time-09-04-34.log

# %%
# call peaks 
proj2<-addReproduciblePeakSet(proj2, groupBy = "Clusters2", plot = FALSE, genomeSize = 2.7e9)
# Out:
# Searching For MACS2..
#
# Found with $path!
#
# ArchR logging to : ArchRLogs/ArchR-addReproduciblePeakSet-18536adc9db3-Date-2020-12-28_Time-09-17-32.log
# If there is an issue, please report to github with logFile!
#
# Calling Peaks with Macs2
#
# 2020-12-28 09:17:32 : Peak Calling Parameters!, 0.004 mins elapsed.
#               Group nCells nCellsUsed nReplicates nMin nMax maxPeaks
# Astro         Astro   1035        540           2   40  500   150000
# INT_Pvalb INT_Pvalb    124        124           2   40   84    62000
# Microglia Microglia    519        519           2   40  479   150000
# MSN_D1       MSN_D1    890        540           2   40  500   150000
# MSN_D2       MSN_D2    925        540           2   40  500   150000
# MSN_SN       MSN_SN     85         85           2   40   45    42500
# Oligo         Oligo   1442        540           2   40  500   150000
# OPC             OPC    304        304           2   40  264   150000
# 2020-12-28 09:17:32 : Batching Peak Calls!, 0.005 mins elapsed.
#
# 2020-12-28 09:17:32 : Batch Execution w/ safelapply!, 0 mins elapsed.
#
# 2020-12-28 10:02:19 : Identifying Reproducible Peaks!, 44.785 mins elapsed.
#
# 2020-12-28 10:03:14 : Creating Union Peak Set!, 45.699 mins elapsed.
#
# Converged after 8 iterations!
#
# 2020-12-28 10:03:17 : Finished Creating Union Peak Set (293245)!, 45.757 mins elapsed.

# %%
# add peak counts matrix 
proj2 <- addPeakMatrix(proj2)
# Out:
# ArchR logging to : ArchRLogs/ArchR-addPeakMatrix-1853ed60454-Date-2020-12-28_Time-10-03-17.log
# If there is an issue, please report to github with logFile!
#
# 2020-12-28 10:03:18 : Batch Execution w/ safelapply!, 0 mins elapsed.
#
# 2020-12-28 10:03:21 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (1 of 21)!, 0.02 mins elapsed.
#
# 2020-12-28 10:03:40 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (2 of 21)!, 0.338 mins elapsed.
#
# 2020-12-28 10:03:52 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (3 of 21)!, 0.529 mins elapsed.
#
# 2020-12-28 10:04:04 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (4 of 21)!, 0.726 mins elapsed.
#
# 2020-12-28 10:04:14 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (5 of 21)!, 0.896 mins elapsed.
#
# 2020-12-28 10:04:22 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (6 of 21)!, 1.042 mins elapsed.
#
# 2020-12-28 10:04:33 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (7 of 21)!, 1.217 mins elapsed.
#
# 2020-12-28 10:04:46 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (8 of 21)!, 1.429 mins elapsed.
#
# 2020-12-28 10:04:54 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (9 of 21)!, 1.567 mins elapsed.
#
# 2020-12-28 10:05:03 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (10 of 21)!, 1.722 mins elapsed.
#
# 2020-12-28 10:05:12 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (11 of 21)!, 1.868 mins elapsed.
#
# 2020-12-28 10:05:21 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (12 of 21)!, 2.021 mins elapsed.
#
# 2020-12-28 10:05:29 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (13 of 21)!, 2.145 mins elapsed.
#
# 2020-12-28 10:05:36 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (14 of 21)!, 2.273 mins elapsed.
#
# 2020-12-28 10:05:46 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (15 of 21)!, 2.433 mins elapsed.
#
# 2020-12-28 10:05:54 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (16 of 21)!, 2.566 mins elapsed.
#
# 2020-12-28 10:06:02 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (17 of 21)!, 2.703 mins elapsed.
#
# 2020-12-28 10:06:08 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (18 of 21)!, 2.798 mins elapsed.
#
# 2020-12-28 10:06:13 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (19 of 21)!, 2.883 mins elapsed.
#
# 2020-12-28 10:06:21 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (20 of 21)!, 3.016 mins elapsed.
#
# 2020-12-28 10:06:29 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (21 of 21)!, 3.144 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addPeakMatrix-1853ed60454-Date-2020-12-28_Time-10-03-17.log

# %%
proj2 = saveArchRProject(ArchRProj = proj2)
# Out:
# Saving ArchRProject...
#
# Loading ArchRProject...
#
# Successfully loaded ArchRProject!
#
#
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|

# %%
# add motif enrichment matrix
proj2 <- addMotifAnnotations(ArchRProj = proj2, motifSet = "JASPAR2018", name = "Motif")
# Out:
# ArchR logging to : ArchRLogs/ArchR-addMotifAnnotations-185378b9f651-Date-2020-12-28_Time-10-20-02.log
# If there is an issue, please report to github with logFile!
#
# 2020-12-28 10:20:03 : Gettting Motif Set, Species : , 0.004 mins elapsed.
#
# 2020-12-28 10:20:41 : Finding Motif Positions with motifmatchr!, 0.647 mins elapsed.
#
# 2020-12-28 10:33:04 : Creating Motif Overlap Matrix, 13.031 mins elapsed.
#
# 2020-12-28 10:33:16 : Finished Getting Motif Info!, 13.229 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addMotifAnnotations-185378b9f651-Date-2020-12-28_Time-10-20-02.log

# %%
# add motif deviations matrix
proj2 <- addBgdPeaks(proj2)
proj2 <- addDeviationsMatrix(proj2,  peakAnnotation = "Motif", force = TRUE)
# Out:
# Identifying Background Peaks!
#
# Using Previous Background Peaks!
#
# ArchR logging to : ArchRLogs/ArchR-addDeviationsMatrix-18531b9dd7a2-Date-2020-12-28_Time-10-34-07.log
# If there is an issue, please report to github with logFile!
# NULL
# 2020-12-28 10:34:12 : Batch Execution w/ safelapply!, 0 mins elapsed.
#
# 2020-12-28 10:34:13 : chromVAR deviations CAUD_WS1H_STA682A131 (1 of 1) Schep (2017), 0.019 mins elapsed.
#
# 2020-12-28 10:40:55 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 70 of 1404, 5.661 mins elapsed.
#
# 2020-12-28 10:46:50 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 140 of 1404, 11.577 mins elapsed.
#
# 2020-12-28 10:52:17 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 210 of 1404, 17.028 mins elapsed.
#
# 2020-12-28 10:57:45 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 280 of 1404, 22.494 mins elapsed.
#
# 2020-12-28 11:02:20 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 350 of 1404, 27.085 mins elapsed.
#
# 2020-12-28 11:07:40 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 420 of 1404, 32.416 mins elapsed.
#
# 2020-12-28 11:12:53 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 490 of 1404, 37.621 mins elapsed.
#
# 2020-12-28 11:17:03 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 560 of 1404, 41.789 mins elapsed.
#
# 2020-12-28 11:21:14 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 630 of 1404, 45.974 mins elapsed.
#
# 2020-12-28 11:25:33 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 700 of 1404, 50.289 mins elapsed.
#
# 2020-12-28 11:29:58 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 770 of 1404, 54.715 mins elapsed.
#
# 2020-12-28 11:33:58 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 840 of 1404, 58.712 mins elapsed.
#
# 2020-12-28 11:37:45 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 910 of 1404, 62.497 mins elapsed.
#
# 2020-12-28 11:41:54 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 980 of 1404, 66.637 mins elapsed.
#
# 2020-12-28 11:45:47 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 1050 of 1404, 70.528 mins elapsed.
#
# 2020-12-28 11:50:36 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 1120 of 1404, 75.336 mins elapsed.
#
# 2020-12-28 11:55:09 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 1190 of 1404, 79.888 mins elapsed.
#
# 2020-12-28 12:00:53 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 1260 of 1404, 85.626 mins elapsed.
#
# 2020-12-28 12:04:51 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 1330 of 1404, 89.594 mins elapsed.
#
# 2020-12-28 12:09:32 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 1400 of 1404, 94.277 mins elapsed.
#
# 2020-12-28 12:10:09 : Finished Computing Deviations!, 95.941 mins elapsed.
#
# ###########
# 2020-12-28 12:10:09 : Completed Computing Deviations!, 96.034 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-addDeviationsMatrix-18531b9dd7a2-Date-2020-12-28_Time-10-34-07.log

# %%
# add co-accessibility matrix
proj2 <- addCoAccessibility(proj2, reducedDims = "Harmony", dimsToUse = 1:30,
                           scaleDims = TRUE, corCutOff = 0.75, k = 100, 
                           knnIteration = 500, overlapCutoff = 0.8, 
                           maxDist = 1e+05, scaleTo = 10^4, log2Norm = TRUE)
# Out:
# ArchR logging to : ArchRLogs/ArchR-addCoAccessibility-185337d4c613-Date-2020-12-28_Time-12-10-10.log
# If there is an issue, please report to github with logFile!
#
# 2020-12-28 12:10:15 : Computing KNN, 0.09 mins elapsed.
#
# 2020-12-28 12:10:15 : Identifying Non-Overlapping KNN pairs, 0.094 mins elapsed.
#
# 2020-12-28 12:10:18 : Identified 456 Groupings!, 0.141 mins elapsed.
#
# 2020-12-28 12:10:34 : Computing Co-Accessibility chr1 (1 of 21), 0.395 mins elapsed.
#
# 2020-12-28 12:10:54 : Computing Co-Accessibility chr2 (2 of 21), 0.728 mins elapsed.
#
# 2020-12-28 12:11:09 : Computing Co-Accessibility chr3 (3 of 21), 0.98 mins elapsed.
#
# 2020-12-28 12:11:23 : Computing Co-Accessibility chr4 (4 of 21), 1.216 mins elapsed.
#
# 2020-12-28 12:11:36 : Computing Co-Accessibility chr5 (5 of 21), 1.442 mins elapsed.
#
# 2020-12-28 12:11:47 : Computing Co-Accessibility chr6 (6 of 21), 1.62 mins elapsed.
#
# 2020-12-28 12:12:00 : Computing Co-Accessibility chr7 (7 of 21), 1.829 mins elapsed.
#
# 2020-12-28 12:12:15 : Computing Co-Accessibility chr8 (8 of 21), 2.091 mins elapsed.
#
# 2020-12-28 12:12:27 : Computing Co-Accessibility chr9 (9 of 21), 2.281 mins elapsed.
#
# 2020-12-28 12:12:39 : Computing Co-Accessibility chr10 (10 of 21), 2.478 mins elapsed.
#
# 2020-12-28 12:12:51 : Computing Co-Accessibility chr11 (11 of 21), 2.687 mins elapsed.
#
# 2020-12-28 12:13:06 : Computing Co-Accessibility chr12 (12 of 21), 2.937 mins elapsed.
#
# 2020-12-28 12:13:18 : Computing Co-Accessibility chr13 (13 of 21), 3.134 mins elapsed.
#
# 2020-12-28 12:13:29 : Computing Co-Accessibility chr14 (14 of 21), 3.324 mins elapsed.
#
# 2020-12-28 12:13:43 : Computing Co-Accessibility chr15 (15 of 21), 3.547 mins elapsed.
#
# 2020-12-28 12:13:53 : Computing Co-Accessibility chr16 (16 of 21), 3.72 mins elapsed.
#
# 2020-12-28 12:14:06 : Computing Co-Accessibility chr17 (17 of 21), 3.931 mins elapsed.
#
# 2020-12-28 12:14:14 : Computing Co-Accessibility chr18 (18 of 21), 4.075 mins elapsed.
#
# 2020-12-28 12:14:21 : Computing Co-Accessibility chr19 (19 of 21), 4.193 mins elapsed.
#
# 2020-12-28 12:14:33 : Computing Co-Accessibility chr20 (20 of 21), 4.379 mins elapsed.
#
# 2020-12-28 12:14:44 : Computing Co-Accessibility chrX (21 of 21), 4.574 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addCoAccessibility-185337d4c613-Date-2020-12-28_Time-12-10-10.log

# %%
proj2 = saveArchRProject(ArchRProj = proj2)
# Out:
# Saving ArchRProject...
#
# Loading ArchRProject...
#
# Successfully loaded ArchRProject!
#
#
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
