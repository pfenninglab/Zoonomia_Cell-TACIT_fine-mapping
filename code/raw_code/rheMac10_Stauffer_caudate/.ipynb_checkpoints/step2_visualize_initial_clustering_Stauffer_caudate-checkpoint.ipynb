# %%
suppressMessages(library(ArchR))
ss <- function(x, pattern, slot = 1, ...) { sapply(strsplit(x = x, split = pattern, ...), '[', slot) }
options(stringsAsFactors = F)
options(repr.plot.width=11, repr.plot.height=8.5)

# %%
##################################
### set Arrow File parameters ####
addArchRThreads(threads = 10)
addArchRGenome("mm10")
# Out:
# Setting default number of Parallel threads to 10.
#
# Setting default genome to Mm10.

# %%
PROJDIR='../../../data/raw_data/rheMac10/Stauffer_caudate'
ARCHDIR=file.path(PROJDIR,'ArchR_Stauffer_caudate')
proj = loadArchRProject(ARCHDIR)
# Out:
# Successfully loaded ArchRProject!
#
#
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|

# %% [markdown]
# # Make plots

# %%
# # plot the confusion matrix of cell types by subjects
# cM <- confusionMatrix(paste0(proj$Clusters), paste0(proj$Sample))
# cM <- cM / Matrix::colSums(cM)
# p <- pheatmap::pheatmap(
#   mat = as.matrix(cM), 
#   color = paletteContinuous("whiteBlue"), 
#   border_color = "black")
# p

# %%
## make UMAP plots
p1 <- plotEmbedding(ArchRProj = proj, colorBy = "cellColData", 
                    name = "Clusters", embedding = "UMAP")

# p2 <- plotEmbedding(ArchRProj = proj, colorBy = "cellColData", 
#                     name = "Region", embedding = "UMAP")

# p3 <- plotEmbedding(ArchRProj = proj, colorBy = "cellColData", 
#                     name = "Sample", embedding = "UMAP")
# ggAlignPlots(p1, p2, type = "h")
p1
# Out:
# ArchR logging to : ArchRLogs/ArchR-plotEmbedding-53e4065e86042-Date-2020-10-07_Time-21-01-58.log
# If there is an issue, please report to github with logFile!
#
# Getting UMAP Embedding
#
# ColorBy = cellColData
#
# Plotting Embedding
#
# 1
#
#
# ArchR logging successful to : ArchRLogs/ArchR-plotEmbedding-53e4065e86042-Date-2020-10-07_Time-21-01-58.log
# plot without title

# %%
# Broad MSN marker, mouse 2010300C02Rik == human KIAA1211L
# MSN markers, Ppp1r1b = DARPP-32, Bcl11b=Ctip2
markMSN3 = c('Ppp1r1b','Bcl11b','Pde1b','Foxp1','Six3' )
p <- plotEmbedding( ArchRProj = proj, colorBy = "GeneScoreMatrix", 
                    name = markMSN3, embedding = "UMAP")#, imputeWeights = NULL)
p3 <- lapply(p, function(x){
  x + guides(color = FALSE, fill = FALSE) + 
    theme_ArchR(baseSize = 6.5) + theme(plot.margin = unit(c(0, 0, 0, 0), "cm")) +
    theme(  axis.text.x=element_blank(),  axis.ticks.x=element_blank(), 
            axis.text.y=element_blank(),  axis.ticks.y=element_blank())
})
do.call(cowplot::plot_grid, c(list(ncol = 3),p3))
# Out:
# Getting ImputeWeights
#
# ArchR logging to : ArchRLogs/ArchR-plotEmbedding-53e4063cec19b-Date-2020-10-07_Time-21-02-02.log
# If there is an issue, please report to github with logFile!
#
# Getting UMAP Embedding
#
# ColorBy = GeneScoreMatrix
#
# Getting Matrix Values...
#
# 2020-10-07 21:02:02 :
#
# 1
#
#
# Imputing Matrix
#
# Using weights on disk
#
# 1 of 1
#
# Using weights on disk
#
# 1 of 1
#
# Plotting Embedding
#
# 1
# 2
# 3
# 4
# 5
#
#
# ArchR logging successful to : ArchRLogs/ArchR-plotEmbedding-53e4063cec19b-Date-2020-10-07_Time-21-02-02.log
# plot without title

# %%
markMSN1 = c('Drd1','Tac1','Foxp2','Slc35d3','Chrm4', 'Pdyn') # D1 markers

# D1 MSN
p <- plotEmbedding( ArchRProj = proj, colorBy = "GeneScoreMatrix", 
                    name = markMSN1, embedding = "UMAP")#, imputeWeights = NULL) # 
p1 <- lapply(p, function(x){
  x + guides(color = FALSE, fill = FALSE) + 
    theme_ArchR(baseSize = 6.5) +
    theme(plot.margin = unit(c(0, 0, 0, 0), "cm")) +
    theme( axis.text.x=element_blank(),  axis.ticks.x=element_blank(), 
           axis.text.y=element_blank(),  axis.ticks.y=element_blank())
})
do.call(cowplot::plot_grid, c(list(ncol = 3),p1))
# Out:
# Getting ImputeWeights
#
# ArchR logging to : ArchRLogs/ArchR-plotEmbedding-53e40740fc468-Date-2020-10-07_Time-21-02-10.log
# If there is an issue, please report to github with logFile!
#
# Getting UMAP Embedding
#
# ColorBy = GeneScoreMatrix
#
# Getting Matrix Values...
#
# 2020-10-07 21:02:10 :
#
# 1
#
#
# Imputing Matrix
#
# Using weights on disk
#
# 1 of 1
#
# Using weights on disk
#
# 1 of 1
#
# Plotting Embedding
#
# 1
# 2
# 3
# 4
# 5
# 6
#
#
# ArchR logging successful to : ArchRLogs/ArchR-plotEmbedding-53e40740fc468-Date-2020-10-07_Time-21-02-10.log
# plot without title

# %%
markMSN2 = c('Drd2','Adora2a','Penk', 'Grik3', 'Sp9', 'Gpr52')# D2 markers

# D2 MSN
p <- plotEmbedding( ArchRProj = proj, colorBy = "GeneScoreMatrix", 
                    name = markMSN2, embedding = "UMAP")#, imputeWeights = NULL)
p2 <- lapply(p, function(x){
  x + guides(color = FALSE, fill = FALSE) + 
    theme_ArchR(baseSize = 6.5) + theme(plot.margin = unit(c(0, 0, 0, 0), "cm")) +
    theme(  axis.text.x=element_blank(),  axis.ticks.x=element_blank(), 
            axis.text.y=element_blank(),  axis.ticks.y=element_blank())
})
do.call(cowplot::plot_grid, c(list(ncol = 3),p2))
# Out:
# Getting ImputeWeights
#
# ArchR logging to : ArchRLogs/ArchR-plotEmbedding-53e405718754f-Date-2020-10-07_Time-21-02-16.log
# If there is an issue, please report to github with logFile!
#
# Getting UMAP Embedding
#
# ColorBy = GeneScoreMatrix
#
# Getting Matrix Values...
#
# 2020-10-07 21:02:17 :
#
# 1
#
#
# Imputing Matrix
#
# Using weights on disk
#
# 1 of 1
#
# Using weights on disk
#
# 1 of 1
#
# Plotting Embedding
#
# 1
# 2
# 3
# 4
# 5
# 6
#
#
# ArchR logging successful to : ArchRLogs/ArchR-plotEmbedding-53e405718754f-Date-2020-10-07_Time-21-02-16.log
# plot without title

# %%
## Neuron vs. Glia markers
markerGenes1  <- c('Rbfox3', # Neuron
                   'Lhx6', #Interneuron
                   'Aqp4', # Astrocyte
                   'Cx3cr1', # Microglia
                   'Pdgfra', #OPC
                   'Mog' # Oligo
                  )

p <- plotEmbedding( ArchRProj = proj, colorBy = "GeneScoreMatrix", 
                    name = markerGenes1, embedding = "UMAP") #, imputeWeights = NULL)
p <- lapply(p, function(x){
  x + guides(color = FALSE, fill = FALSE) + 
    theme_ArchR(baseSize = 6.5) + theme(plot.margin = unit(c(0, 0, 0, 0), "cm")) +
    theme(  axis.text.x=element_blank(),  axis.ticks.x=element_blank(), 
            axis.text.y=element_blank(),  axis.ticks.y=element_blank())
})
do.call(cowplot::plot_grid, c(list(ncol = 3),p))
# Out:
# Getting ImputeWeights
#
# ArchR logging to : ArchRLogs/ArchR-plotEmbedding-53e40618da111-Date-2020-10-07_Time-21-02-24.log
# If there is an issue, please report to github with logFile!
#
# Getting UMAP Embedding
#
# ColorBy = GeneScoreMatrix
#
# Getting Matrix Values...
#
# 2020-10-07 21:02:24 :
#
# 1
#
#
# Imputing Matrix
#
# Using weights on disk
#
# 1 of 1
#
# Using weights on disk
#
# 1 of 1
#
# Plotting Embedding
#
# 1
# 2
# 3
# 4
# 5
# 6
#
#
# ArchR logging successful to : ArchRLogs/ArchR-plotEmbedding-53e40618da111-Date-2020-10-07_Time-21-02-24.log
# plot without title

# %% [markdown]
# # Relabel cluster and call peaks

# %%
############################################
# using marker gene scores, give cluster names
remapClust <- c(
    'C1' = 'Microglia',
    'C2' = 'MSN_D1',
    'C3' = 'MSN_D2',
    'C4' = 'MSN_D1',
    'C5'='MSN_UNK1',
    'C6'='MSN_D1',
    'C7'='MSN_D2',
    'C8'='OPC',
    'C9'='Oligo',
    'C10'='Oligo',
    'C11'='Drop',
    'C12'='Drop',
    'C13'='Astro',
    'C14'='Astro',
    'C15'='Interneuron',
    'C16'='Interneuron',
    'C17'='Interneuron'
)
proj$Clusters2 <- mapLabels(proj$Clusters, newLabels = remapClust, 
                            oldLabels = names(remapClust))
table(proj$Clusters2)
# Out:
#       Astro        Drop Interneuron   Microglia      MSN_D1      MSN_D2
#        1035         125         193         519         975         925
#    MSN_UNK1       Oligo         OPC
#         400        1442         304

# %%
## make UMAP plots
p1 <- plotEmbedding(ArchRProj = proj, colorBy = "cellColData", 
                    name = "Clusters2", embedding = "UMAP")

p1
# Out:
# ArchR logging to : ArchRLogs/ArchR-plotEmbedding-53e406cb00a16-Date-2020-10-07_Time-21-03-55.log
# If there is an issue, please report to github with logFile!
#
# Getting UMAP Embedding
#
# ColorBy = cellColData
#
# Plotting Embedding
#
# 1
#
#
# ArchR logging successful to : ArchRLogs/ArchR-plotEmbedding-53e406cb00a16-Date-2020-10-07_Time-21-03-55.log
# plot without title

# %%
# drop the drop clusters
ARCHDIR2=file.path(PROJDIR,'ArchR_Stauffer_caudate_labeled')
idxSample <- BiocGenerics::which(proj$Clusters2 %ni% "Drop")
cellsSample <- proj$cellNames[idxSample]

proj2 = subsetArchRProject(
  ArchRProj = proj,
  cells = cellsSample,
  outputDirectory = ARCHDIR2
)
# Out:
# Copying ArchRProject to new outputDirectory : /home/bnphan/projects/snATAC_cross_species_caudate/data/raw_data/rheMac10/Stauffer_caudate/ArchR_Stauffer_caudate_labeled
#
# Copying Arrow Files...
#
# .copyArrow : Initializing Out ArrowFile
#
# .copyArrow : Adding Metadata to Out ArrowFile
#
# .copyArrow : Adding SubMatrices to Out ArrowFile
#
# Getting ImputeWeights
#
# Dropping ImputeWeights...
#
# Copying Other Files...
#
# Copying Other Files (1 of 2): Embeddings
#
# Copying Other Files (2 of 2): IterativeLSI
#
# Saving ArchRProject...
#
# Loading ArchRProject...
#
# Successfully loaded ArchRProject!
#
#
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|

# %%
# make group coverage, call peaks, and 
proj2<-addGroupCoverages(proj2, groupBy="Clusters2", force = TRUE)
# Out:
# ArchR logging to : ArchRLogs/ArchR-addGroupCoverages-53e406381f491-Date-2020-10-07_Time-21-07-10.log
# If there is an issue, please report to github with logFile!
#
# Astro (1 of 8) : CellGroups N = 2
#
# Interneuron (2 of 8) : CellGroups N = 2
#
# Microglia (3 of 8) : CellGroups N = 2
#
# MSN_D1 (4 of 8) : CellGroups N = 2
#
# MSN_D2 (5 of 8) : CellGroups N = 2
#
# MSN_UNK1 (6 of 8) : CellGroups N = 2
#
# Oligo (7 of 8) : CellGroups N = 2
#
# OPC (8 of 8) : CellGroups N = 2
#
# 2020-10-07 21:07:10 : Further Sampled 2 Groups above the Max Fragments!, 0.009 mins elapsed.
#
# 2020-10-07 21:07:10 : Creating Coverage Files!, 0.011 mins elapsed.
#
# 2020-10-07 21:07:10 : Batch Execution w/ safelapply!, 0.011 mins elapsed.
#
# 2020-10-07 21:13:12 : Adding Kmer Bias to Coverage Files!, 6.032 mins elapsed.
#
# Completed Kmer Bias Calculation
#
# Adding Kmer Bias (1 of 16)
#
# Adding Kmer Bias (2 of 16)
#
# Adding Kmer Bias (3 of 16)
#
# Adding Kmer Bias (4 of 16)
#
# Adding Kmer Bias (5 of 16)
#
# Adding Kmer Bias (6 of 16)
#
# Adding Kmer Bias (7 of 16)
#
# Adding Kmer Bias (8 of 16)
#
# Adding Kmer Bias (9 of 16)
#
# Adding Kmer Bias (10 of 16)
#
# Adding Kmer Bias (11 of 16)
#
# Adding Kmer Bias (12 of 16)
#
# Adding Kmer Bias (13 of 16)
#
# Adding Kmer Bias (14 of 16)
#
# Adding Kmer Bias (15 of 16)
#
# Adding Kmer Bias (16 of 16)
#
# 2020-10-07 21:18:56 : Finished Creation of Coverage Files!, 11.778 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addGroupCoverages-53e406381f491-Date-2020-10-07_Time-21-07-10.log

# %%
# call peaks 
proj2<-addReproduciblePeakSet(proj2, groupBy = "Clusters2", plot = FALSE, genomeSize = 2.7e9)
# Out:
# Searching For MACS2..
#
# Found with $path!
#
# ArchR logging to : ArchRLogs/ArchR-addReproduciblePeakSet-53e403c43705a-Date-2020-10-07_Time-21-18-57.log
# If there is an issue, please report to github with logFile!
#
# Calling Peaks with Macs2
#
# 2020-10-07 21:18:57 : Peak Calling Parameters!, 0.003 mins elapsed.
#                   Group nCells nCellsUsed nReplicates nMin nMax maxPeaks
# Astro             Astro   1035        540           2   40  500   150000
# Interneuron Interneuron    193        193           2   40  153    96500
# Microglia     Microglia    519        519           2   40  479   150000
# MSN_D1           MSN_D1    975        540           2   40  500   150000
# MSN_D2           MSN_D2    925        540           2   40  500   150000
# MSN_UNK1       MSN_UNK1    400        400           2   40  360   150000
# Oligo             Oligo   1442        540           2   40  500   150000
# OPC                 OPC    304        304           2   40  264   150000
# 2020-10-07 21:18:57 : Batching Peak Calls!, 0.004 mins elapsed.
#
# 2020-10-07 21:18:57 : Batch Execution w/ safelapply!, 0 mins elapsed.
#
# 2020-10-07 21:56:50 : Identifying Reproducible Peaks!, 37.878 mins elapsed.
#
# 2020-10-07 21:57:34 : Creating Union Peak Set!, 38.612 mins elapsed.
#
# Converged after 6 iterations!
#
# 2020-10-07 21:57:36 : Finished Creating Union Peak Set (293503)!, 38.653 mins elapsed.

# %%
# add peak counts matrix 
proj2 <- addPeakMatrix(proj2)
# Out:
# ArchR logging to : ArchRLogs/ArchR-addPeakMatrix-53e40690944a-Date-2020-10-07_Time-21-57-36.log
# If there is an issue, please report to github with logFile!
#
# 2020-10-07 21:57:36 : Batch Execution w/ safelapply!, 0 mins elapsed.
#
# 2020-10-07 21:57:38 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (1 of 21)!, 0.017 mins elapsed.
#
# 2020-10-07 21:57:53 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (2 of 21)!, 0.269 mins elapsed.
#
# 2020-10-07 21:58:02 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (3 of 21)!, 0.416 mins elapsed.
#
# 2020-10-07 21:58:10 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (4 of 21)!, 0.547 mins elapsed.
#
# 2020-10-07 21:58:17 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (5 of 21)!, 0.661 mins elapsed.
#
# 2020-10-07 21:58:23 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (6 of 21)!, 0.768 mins elapsed.
#
# 2020-10-07 21:58:30 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (7 of 21)!, 0.88 mins elapsed.
#
# 2020-10-07 21:58:39 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (8 of 21)!, 1.027 mins elapsed.
#
# 2020-10-07 21:58:45 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (9 of 21)!, 1.132 mins elapsed.
#
# 2020-10-07 21:58:51 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (10 of 21)!, 1.237 mins elapsed.
#
# 2020-10-07 21:58:58 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (11 of 21)!, 1.343 mins elapsed.
#
# 2020-10-07 21:59:04 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (12 of 21)!, 1.449 mins elapsed.
#
# 2020-10-07 21:59:09 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (13 of 21)!, 1.535 mins elapsed.
#
# 2020-10-07 21:59:15 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (14 of 21)!, 1.622 mins elapsed.
#
# 2020-10-07 21:59:21 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (15 of 21)!, 1.733 mins elapsed.
#
# 2020-10-07 21:59:27 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (16 of 21)!, 1.837 mins elapsed.
#
# 2020-10-07 21:59:33 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (17 of 21)!, 1.935 mins elapsed.
#
# 2020-10-07 21:59:37 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (18 of 21)!, 2.002 mins elapsed.
#
# 2020-10-07 21:59:41 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (19 of 21)!, 2.06 mins elapsed.
#
# 2020-10-07 21:59:46 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (20 of 21)!, 2.142 mins elapsed.
#
# 2020-10-07 21:59:51 : Adding CAUD_WS1H_STA682A131 to PeakMatrix for Chr (21 of 21)!, 2.23 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addPeakMatrix-53e40690944a-Date-2020-10-07_Time-21-57-36.log

# %%
# add motif enrichment matrix
proj2 <- addMotifAnnotations(ArchRProj = proj2, motifSet = "JASPAR2018", name = "Motif")
# Out:
# ArchR logging to : ArchRLogs/ArchR-addMotifAnnotations-53e407f643215-Date-2020-10-07_Time-22-09-37.log
# If there is an issue, please report to github with logFile!
#
# 2020-10-07 22:09:37 : Gettting Motif Set, Species : , 0.003 mins elapsed.
#
# 2020-10-07 22:10:03 : Finding Motif Positions with motifmatchr!, 0.432 mins elapsed.
#
# 2020-10-07 22:19:51 : Creating Motif Overlap Matrix, 10.24 mins elapsed.
#
# 2020-10-07 22:20:00 : Finished Getting Motif Info!, 10.391 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addMotifAnnotations-53e407f643215-Date-2020-10-07_Time-22-09-37.log

# %%
# add motif deviations matrix
proj2 <- addBgdPeaks(proj2)
proj2 <- addDeviationsMatrix(proj2,  peakAnnotation = "Motif", force = TRUE)
# Out:
# Identifying Background Peaks!
#
# Using Previous Background Peaks!
#
# ArchR logging to : ArchRLogs/ArchR-addDeviationsMatrix-53e402caf8899-Date-2020-10-07_Time-22-20-22.log
# If there is an issue, please report to github with logFile!
# NULL
# 2020-10-07 22:20:27 : Batch Execution w/ safelapply!, 0 mins elapsed.
#
# 2020-10-07 22:20:28 : chromVAR deviations CAUD_WS1H_STA682A131 (1 of 1) Schep (2017), 0.017 mins elapsed.
#
# 2020-10-07 22:26:17 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 70 of 1404, 5.19 mins elapsed.
#
# 2020-10-07 22:31:39 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 140 of 1404, 10.566 mins elapsed.
#
# 2020-10-07 22:36:40 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 210 of 1404, 15.581 mins elapsed.
#
# 2020-10-07 22:41:44 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 280 of 1404, 20.641 mins elapsed.
#
# 2020-10-07 22:45:57 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 350 of 1404, 24.872 mins elapsed.
#
# 2020-10-07 22:50:55 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 420 of 1404, 29.828 mins elapsed.
#
# 2020-10-07 22:55:40 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 490 of 1404, 34.573 mins elapsed.
#
# 2020-10-07 22:59:35 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 560 of 1404, 38.497 mins elapsed.
#
# 2020-10-07 23:03:32 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 630 of 1404, 42.441 mins elapsed.
#
# 2020-10-07 23:07:34 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 700 of 1404, 46.484 mins elapsed.
#
# 2020-10-07 23:11:44 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 770 of 1404, 50.651 mins elapsed.
#
# 2020-10-07 23:15:32 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 840 of 1404, 54.454 mins elapsed.
#
# 2020-10-07 23:19:05 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 910 of 1404, 57.999 mins elapsed.
#
# 2020-10-07 23:22:57 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 980 of 1404, 61.87 mins elapsed.
#
# 2020-10-07 23:26:37 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 1050 of 1404, 65.533 mins elapsed.
#
# 2020-10-07 23:31:06 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 1120 of 1404, 70.014 mins elapsed.
#
# 2020-10-07 23:35:20 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 1190 of 1404, 74.248 mins elapsed.
#
# 2020-10-07 23:40:33 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 1260 of 1404, 79.465 mins elapsed.
#
# 2020-10-07 23:44:19 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 1330 of 1404, 83.223 mins elapsed.
#
# 2020-10-07 23:48:37 : CAUD_WS1H_STA682A131 (1 of 1) : Deviations for Annotation 1400 of 1404, 87.533 mins elapsed.
#
# 2020-10-07 23:49:03 : Finished Computing Deviations!, 88.602 mins elapsed.
#
# ###########
# 2020-10-07 23:49:03 : Completed Computing Deviations!, 88.68 mins elapsed.
# ###########
#
# ArchR logging successful to : ArchRLogs/ArchR-addDeviationsMatrix-53e402caf8899-Date-2020-10-07_Time-22-20-22.log

# %%
# add co-accessibility matrix
proj2 <- addCoAccessibility(proj2, reducedDims = "Harmony", dimsToUse = 1:30,
                           scaleDims = TRUE, corCutOff = 0.75, k = 100, 
                           knnIteration = 500, overlapCutoff = 0.8, 
                           maxDist = 1e+05, scaleTo = 10^4, log2Norm = TRUE)
# Out:
# ArchR logging to : ArchRLogs/ArchR-addCoAccessibility-53e401884b775-Date-2020-10-07_Time-23-49-04.log
# If there is an issue, please report to github with logFile!
#
# 2020-10-07 23:49:04 : Computing KNN, 0.003 mins elapsed.
#
# 2020-10-07 23:49:04 : Identifying Non-Overlapping KNN pairs, 0.004 mins elapsed.
#
# 2020-10-07 23:49:06 : Identified 460 Groupings!, 0.038 mins elapsed.
#
# 2020-10-07 23:49:07 : Computing Co-Accessibility chr1 (1 of 21), 0.059 mins elapsed.
#
# 2020-10-07 23:49:20 : Computing Co-Accessibility chr2 (2 of 21), 0.277 mins elapsed.
#
# 2020-10-07 23:49:29 : Computing Co-Accessibility chr3 (3 of 21), 0.425 mins elapsed.
#
# 2020-10-07 23:49:38 : Computing Co-Accessibility chr4 (4 of 21), 0.572 mins elapsed.
#
# 2020-10-07 23:49:47 : Computing Co-Accessibility chr5 (5 of 21), 0.724 mins elapsed.
#
# 2020-10-07 23:49:53 : Computing Co-Accessibility chr6 (6 of 21), 0.829 mins elapsed.
#
# 2020-10-07 23:50:01 : Computing Co-Accessibility chr7 (7 of 21), 0.951 mins elapsed.
#
# 2020-10-07 23:50:11 : Computing Co-Accessibility chr8 (8 of 21), 1.121 mins elapsed.
#
# 2020-10-07 23:50:17 : Computing Co-Accessibility chr9 (9 of 21), 1.227 mins elapsed.
#
# 2020-10-07 23:50:24 : Computing Co-Accessibility chr10 (10 of 21), 1.342 mins elapsed.
#
# 2020-10-07 23:50:31 : Computing Co-Accessibility chr11 (11 of 21), 1.464 mins elapsed.
#
# 2020-10-07 23:50:39 : Computing Co-Accessibility chr12 (12 of 21), 1.588 mins elapsed.
#
# 2020-10-07 23:50:45 : Computing Co-Accessibility chr13 (13 of 21), 1.684 mins elapsed.
#
# 2020-10-07 23:50:51 : Computing Co-Accessibility chr14 (14 of 21), 1.791 mins elapsed.
#
# 2020-10-07 23:50:59 : Computing Co-Accessibility chr15 (15 of 21), 1.923 mins elapsed.
#
# 2020-10-07 23:51:05 : Computing Co-Accessibility chr16 (16 of 21), 2.024 mins elapsed.
#
# 2020-10-07 23:51:12 : Computing Co-Accessibility chr17 (17 of 21), 2.139 mins elapsed.
#
# 2020-10-07 23:51:16 : Computing Co-Accessibility chr18 (18 of 21), 2.212 mins elapsed.
#
# 2020-10-07 23:51:20 : Computing Co-Accessibility chr19 (19 of 21), 2.279 mins elapsed.
#
# 2020-10-07 23:51:26 : Computing Co-Accessibility chr20 (20 of 21), 2.377 mins elapsed.
#
# 2020-10-07 23:51:32 : Computing Co-Accessibility chrX (21 of 21), 2.476 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addCoAccessibility-53e401884b775-Date-2020-10-07_Time-23-49-04.log

# %%
proj2 = saveArchRProject(ArchRProj = proj2)
# Out:
# Saving ArchRProject...
#
# Loading ArchRProject...
#
# Successfully loaded ArchRProject!
#
#
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
